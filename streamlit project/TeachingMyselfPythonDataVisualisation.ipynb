# %% [markdown]
#  Tutorial - Sheila Kirwan

# %%
import numpy as np
import pandas as pd
from pandas import Series
from pandas import Dataframe
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 4
#       2 import pandas as pd
#       3 from pandas import Series
# ----> 4 from pandas import Dataframe
#       5 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'Dataframe' from 'pandas' (C:\Users\User\PythonFinalProject\streamlit project\streamlitenv\Lib\site-packages\pandas\__init__.py)

# %%
address = 'C:/Users/User/OneDrive/Documents/Final Project/Data for Analysis/working folder/RandomGeneratedRateData - V1.csv'
participants = pd.read_csv(address)
participants.columns = ['Event Name', 'Order Timestamp', 'Status', 'Order ID', 'Barcode', 'TicketType', 'First Name', 'Last Name', 'email', 'email', 'Gender', 'Address Line 1', 'Address Line 2', 'Address Line 3', 'Country', 'County', 'Eircode Postcode', 'Date of Birth', 'Mobile', 'Do you have any medical conditions allergies?', 'Do you have any dietary requirements?', 'Emergency Contact Name', 'Emergency Contact Phone', 'Public health measures for COVID-19', 'I have read  and agree to abide by the above Public health measures for COVID-19', 'understand', 'and agree to abide by the above Public health measures for COVID-19', 'I accept event waiver', 'Privacy Policy', 'Refund and Transfer Policy', 'I have read the Privacy Refund & Transfer Policies', 'Update me of similar events', 'Cycling Ireland Licence Number', 'Club', 'Rider Category', 'UCI ID', 'Date of Purchase', 'Active Order Number', 'Active CI Member', 'Active CI Number', 'Active County', 'Active Mobile', 'Has Membership', 'CI Licence Number', 'CI Club', 'CI mid', 'CI Rider Category', 'Payment Type', 'Selling Mode', 'Ticket Price', 'Ticket Fee', 'Discount', 'Discount Amount', 'Discount Code Used', 'Total Price Paid Per Ticket', 'Timeslot Name', 'Timeslot Date', 'Booking Date', 'Booking Month', 'Race Number', 'Access Code', 'Comment', 'Additional Purchases', 'Additional Purchases Details', 'Additional Purchases Options', 'Additional Purchases Variants', 'Additional Purchases Total Paid', 'Charity', 'Page URL', 'Raised', 'Fundraiser Status']
parse_eventnames=['Event Name']
participants.head()
# Out:
#         Event Name Order Timestamp     Status    Order ID   Barcode  \
# 0      Cycle Clare     Jun 1, 2021  CANCELLED   551292262  87243922
# 1      Cycle Clare     Nov 7, 2020  CANCELLED  7465343309  90056557
# 2  Cycle Waterford     Dec 4, 2021      VALID  4907232096  88286113
# 3     Cycle Dublin    Aug 28, 2021      VALID  8082213571  89520464
# 4      Cycle Kerry    Jun 28, 2021    INVALID  4804979387  86175213
#
#   TicketType First Name  Last Name                 email  \
# 0      100KM     Hakeem  Alexander        vel@google.org
# 1      100KM  Whilemina     Booker   quis.pede@icloud.ca
# 2       30KM      Noble  Mccormick       erat@google.org
# 3       30KM      Lewis       Snow  risus@protonmail.net
# 4      100KM    Giacomo      Horne       amet@google.edu
#
#                   email  ... Comment Additional Purchases  \
# 0        vel@google.org  ...     NaN                  Yes
# 1   quis.pede@icloud.ca  ...     NaN                  Yes
# ...

# %%
participants.shape
# Out:
# (5500, 71)

# %%
participants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 71 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   Event Name                                                                        5500 non-null   object
#  1   Order Timestamp                                                                   5500 non-null   object
#  2   Status                                                                            5500 non-null   object
#  3   Order ID                                                                          5500 non-null   int64
#  4   Barcode                                                                           5500 non-null   int64
# ...

# %%
participants.describe()
# Out:
#            Order ID       Barcode  Public health measures for COVID-19  \
# count  5.500000e+03  5.500000e+03                                  0.0
# mean   4.996623e+09  8.995066e+07                                  NaN
# std    2.905547e+09  5.745339e+06                                  NaN
# min    6.154780e+05  8.000019e+07                                  NaN
# 25%    2.435268e+09  8.496293e+07                                  NaN
# 50%    4.956554e+09  8.986828e+07                                  NaN
# 75%    7.530760e+09  9.491327e+07                                  NaN
# max    9.998843e+09  9.999328e+07                                  NaN
#
#        I have read  and agree to abide by the above Public health measures for COVID-19  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# ...

# %%
participants.shape
# Out:
# (5500, 71)

# %%
participants['Total Price Paid Per Ticket'].mean()
# Out:
# 51.029636363636364

# %%
participants['Total Price Paid Per Ticket'].median()
# Out:
# 51.2

# %%
participants['Total Price Paid Per Ticket'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
participants['Ticket Price'].plot(kind='density', figsize=(14,6)) #Density plot of Ticket price over time
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
ax = participants['Ticket Price'].plot(kind='density', figsize=(14,6)) #Density plot of Ticket price over time
ax.axvline(participants['Ticket Price'].mean(), color ='red') #mean of the ticket Price is 55
ax.axvline(participants['Ticket Price'].median(), color ='green')#median of the ticket Price is 60

# %%
ax = participants['Ticket Price'].plot(kind='hist', figsize=(14,6)) #histogram plot of Ticket price over time
ax.set_ylabel('Number of Sales') #adding a label to the y axis
ax.set_xlabel('Euros per Ticket') #adding a label to the x axis
# Out:
# Text(0.5, 0, 'Euros')

# %%
participants.head()
# Out:
#         Event Name Order Timestamp     Status    Order ID   Barcode  \
# 0      Cycle Clare     Jun 1, 2021  CANCELLED   551292262  87243922
# 1      Cycle Clare     Nov 7, 2020  CANCELLED  7465343309  90056557
# 2  Cycle Waterford     Dec 4, 2021      VALID  4907232096  88286113
# 3     Cycle Dublin    Aug 28, 2021      VALID  8082213571  89520464
# 4      Cycle Kerry    Jun 28, 2021    INVALID  4804979387  86175213
#
#   TicketType First Name  Last Name                 email  \
# 0      100KM     Hakeem  Alexander        vel@google.org
# 1      100KM  Whilemina     Booker   quis.pede@icloud.ca
# 2       30KM      Noble  Mccormick       erat@google.org
# 3       30KM      Lewis       Snow  risus@protonmail.net
# 4      100KM    Giacomo      Horne       amet@google.edu
#
#                   email  ... Comment Additional Purchases  \
# 0        vel@google.org  ...     NaN                  Yes
# 1   quis.pede@icloud.ca  ...     NaN                  Yes
# ...

# %%
participants['Gender'].value_counts() #counts rows of Gender in the file called participants
# Out:
# female    2776
# male      2724
# Name: Gender, dtype: int64

# %%
participants['Gender'].value_counts().plot(kind='pie', figsize=(6,6)) #counts rows of Gender in the file called participants
# Out:
# <AxesSubplot: ylabel='Gender'>

# %%
ax = participants['Gender'].value_counts().plot(kind='bar',figsize=(14,6))
ax.set_ylabel=('Number of Participants')

# %%
fig = plt.figure(figsize=(16,16))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 fig = plt.figure(figsize=(16,16))
#       2 plt.matshow(corr, cmap='RdBu', fignum=fig.number)
#       3 plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
#
# NameError: name 'plt' is not defined

# %%
corr = participants.corr()
corr
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_1824\3137433219.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = participants.corr()
#                                                     Order ID   Barcode  \
# Order ID                                            1.000000  0.016403
# Barcode                                             0.016403  1.000000
# Public health measures for COVID-19                      NaN       NaN
# I have read  and agree to abide by the above Pu...       NaN       NaN
# understand                                               NaN       NaN
# and agree to abide by the above Public health m...       NaN       NaN
# Privacy Policy                                           NaN       NaN
# Refund and Transfer Policy                               NaN       NaN
# ...

# %%
fig = plt.figure(figsize=(16,16))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
participants.plot(kind='scatter', x = 'Event Name', y = 'Raised', figsize=(10,6))
# Out:
# <AxesSubplot: xlabel='Event Name', ylabel='Raised'>

# %%
participants.plot(kind='scatter', x = 'Timeslot Date', y = 'Booking Date', figsize=(15,15))
# Out:
# <AxesSubplot: xlabel='Timeslot Date', ylabel='Booking Date'>

# %%
ax = participants[['Ticket Price','TicketType']].boxplot(by='TicketType',figsize=(10,6))
ax.set_ylabel('Ticket Price')
# Out:
# Text(0, 0.5, 'Ticket Price')

# %%
participants[['Gender','Event Name']].value_counts().plot(kind='pie' figsize=(6,6))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 participants[['Gender','Event Name']].value_counts().plot(kind='pie', subplots='True', figsize=(6,6))
#
# File ~\PythonFinalProject\streamlit project\streamlitenv\Lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\PythonFinalProject\streamlit project\streamlitenv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# ...

# %%
def label_function(val):
    return f'{val / 100 * len(participants):.0f}\n{val:.0f}%'


fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

participants.groupby('Event Name').size().plot(kind='pie', autopct=label_function, textprops={'fontsize':10 },
                                  colors=['tomato', 'brown', 'skyblue', 'green','yellow', 'pink', 'royalblue'], ax=ax1)
participants.groupby('Gender').size().plot(kind='pie', autopct=label_function, textprops={'fontsize':10 },
                                 colors=['violet', 'lime'], ax=ax2)
ax1.set_ylabel('Per Event Name', size=22)
ax2.set_ylabel('Per Gender', size=22)
plt.tight_layout()
plt.show()

# %%
participants = pd.DataFrame(np.random.randn(50, 4), 
        index=pd.date_range('1/1/2000', periods=50), columns=list('ABCD'))
participants = participants.cumsum()
participants.plot(style=['+-','o-','.--','s:'])# example of using different makers for each marker.
participants.plot();

# %%
b = np.matrix([[1, 2], [3, 4]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b = np.matrix([[1, 2], [3, 4]])
#
# NameError: name 'np' is not defined

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
print(b_asarray)
# Out:
# [[1 2]
#  [3 4]]

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
from pandas import Series
from pandas import Dataframe
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 4
#       2 import pandas as pd
#       3 from pandas import Series
# ----> 4 from pandas import Dataframe
#       5 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'Dataframe' from 'pandas' (C:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py)

# %%
participants.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 participants.head()
#
# NameError: name 'participants' is not defined

# %%
address = 'C:/Users/User/OneDrive/Documents/Final Project/Data for Analysis/working folder/RandomGeneratedRateData - V1.csv'
participants = pd.read_csv(address)
participants.columns = ['Event Name', 'Order Timestamp', 'Status', 'Order ID', 'Barcode', 'TicketType', 'First Name', 'Last Name', 'email', 'email', 'Gender', 'Address Line 1', 'Address Line 2', 'Address Line 3', 'Country', 'County', 'Eircode Postcode', 'Date of Birth', 'Mobile', 'Do you have any medical conditions allergies?', 'Do you have any dietary requirements?', 'Emergency Contact Name', 'Emergency Contact Phone', 'Public health measures for COVID-19', 'I have read  and agree to abide by the above Public health measures for COVID-19', 'understand', 'and agree to abide by the above Public health measures for COVID-19', 'I accept event waiver', 'Privacy Policy', 'Refund and Transfer Policy', 'I have read the Privacy Refund & Transfer Policies', 'Update me of similar events', 'Cycling Ireland Licence Number', 'Club', 'Rider Category', 'UCI ID', 'Date of Purchase', 'Active Order Number', 'Active CI Member', 'Active CI Number', 'Active County', 'Active Mobile', 'Has Membership', 'CI Licence Number', 'CI Club', 'CI mid', 'CI Rider Category', 'Payment Type', 'Selling Mode', 'Ticket Price', 'Ticket Fee', 'Discount', 'Discount Amount', 'Discount Code Used', 'Total Price Paid Per Ticket', 'Timeslot Name', 'Timeslot Date', 'Booking Date', 'Booking Month', 'Race Number', 'Access Code', 'Comment', 'Additional Purchases', 'Additional Purchases Details', 'Additional Purchases Options', 'Additional Purchases Variants', 'Additional Purchases Total Paid', 'Charity', 'Page URL', 'Raised', 'Fundraiser Status']
parse_eventnames=['Event Name']
participants.head()
# Out:
#         Event Name Order Timestamp     Status    Order ID   Barcode  \
# 0      Cycle Clare     Jun 1, 2021  CANCELLED   551292262  87243922
# 1      Cycle Clare     Nov 7, 2020  CANCELLED  7465343309  90056557
# 2  Cycle Waterford     Dec 4, 2021      VALID  4907232096  88286113
# 3     Cycle Dublin    Aug 28, 2021      VALID  8082213571  89520464
# 4      Cycle Kerry    Jun 28, 2021    INVALID  4804979387  86175213
#
#   TicketType First Name  Last Name                 email  \
# 0      100KM     Hakeem  Alexander        vel@google.org
# 1      100KM  Whilemina     Booker   quis.pede@icloud.ca
# 2       30KM      Noble  Mccormick       erat@google.org
# 3       30KM      Lewis       Snow  risus@protonmail.net
# 4      100KM    Giacomo      Horne       amet@google.edu
#
#                   email  ... Comment Additional Purchases  \
# 0        vel@google.org  ...     NaN                  Yes
# 1   quis.pede@icloud.ca  ...     NaN                  Yes
# ...

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b');

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend();
