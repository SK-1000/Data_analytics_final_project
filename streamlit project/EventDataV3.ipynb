# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt

# %%
address = 'C:/Users/User/OneDrive/Documents/Final Project/Data for Analysis/working folder/RandomGeneratedRateData - V3.csv'
df = pd.read_csv(address)
parse_ages=['Ages']
df.head()
# Out:
#       Event Name Order Timestamp   Status    Order ID   Barcode TicketType  \
# 0   Cycle Dublin    Sep 27, 2020  INVALID  3804359915  81080757      100KM
# 1     Cycle Cork    Jan 18, 2021  INVALID  5787362907  91029595      100KM
# 2    Cycle Clare    Oct 26, 2020    VALID  2321494947  80266185       50KM
# 3  Cycle Wicklow    Nov 17, 2020  INVALID  8323803214  97735556       50KM
# 4   Cycle Galway    Apr 27, 2021    VALID  9084969052  93750054       50KM
#
#   First Name  Last Name                           email  \
# 0    Ignacia  Gutierrez        convallis.in@hotmail.edu
# 1      Thane  Christian      porttitor.eros.nec@aol.org
# 2    Anthony     Dawson           tristique@hotmail.edu
# 3    Charles   Mcdaniel               nam.ac@google.edu
# 4     Shelly       Wong  neque.pellentesque@hotmail.net
#
#                           email.1  ... Comment Additional Purchases  \
# 0        convallis.in@hotmail.edu  ...     NaN                   No
# ...
